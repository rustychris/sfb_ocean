# %%
import numpy as np
import xarray as xr
from stompy.grid import unstructured_grid
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#ptm0=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0000.nc')
#avg0=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170601/average.nc_0000.nc')

# %%
ptm5=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0005.nc')
avg5=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170601/average.nc_0005.nc')

# %%
#ptm6=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0006.nc')
#avg6=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170601/average.nc_0006.nc')

# %%
#ptm7=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170701/ptm_average.nc_0000.nc')
#avg7=xr.open_dataset('/opt2/sfb_ocean/suntans/runs/merge_009-20170701/average.nc_0000.nc')

# %%
ptm5
# Out:
# <xarray.Dataset>
# Dimensions:                        (Two: 2, date_string_length: 19, nMaxMesh2_face_nodes: 6, nMesh2_data_time: 226, nMesh2_edge: 108448, nMesh2_face: 57719, nMesh2_layer_3d: 50, nMesh2_node: 50711)
# Coordinates:
#     Mesh2_face_x                   (nMesh2_face) float64 ...
#     Mesh2_face_y                   (nMesh2_face) float64 ...
#     Mesh2_edge_x                   (nMesh2_edge) float64 ...
#     Mesh2_edge_y                   (nMesh2_edge) float64 ...
# Dimensions without coordinates: Two, date_string_length, nMaxMesh2_face_nodes, nMesh2_data_time, nMesh2_edge, nMesh2_face, nMesh2_layer_3d, nMesh2_node
# Data variables:
#     Mesh2_node_x                   (nMesh2_node) float64 ...
#     Mesh2_node_y                   (nMesh2_node) float64 ...
#     Mesh2_edge_bc                  (nMesh2_edge) float64 ...
#     Mesh2_edge_nodes               (nMesh2_edge, Two) float64 ...
#     Mesh2_edge_faces               (nMesh2_edge, Two) float64 ...
# ...

# %%
avg5.isel
# Out:
# <xarray.Dataset>
# Dimensions:       (Nc: 57719, Ne: 108448, Nk: 50, Nkw: 51, Np: 50711, Two: 2, numsides: 6, time: 240)
# Coordinates:
#     xv            (Nc) float64 ...
#     yv            (Nc) float64 ...
#     xe            (Ne) float64 ...
#     ye            (Ne) float64 ...
#     z_r           (Nk) float64 ...
#     z_w           (Nkw) float64 ...
#     Nk            (Nc) int32 ...
#   * time          (time) datetime64[ns] 2017-06-26 ... 2017-06-30T23:30:00
# Dimensions without coordinates: Nc, Ne, Nkw, Np, Two, numsides
# Data variables:
#     suntans_mesh  int32 ...
#     cells         (Nc, numsides) int32 ...
#     nfaces        (Nc) int32 ...
#     face          (Nc, numsides) int32 ...
#     edges         (Ne, Two) int32 ...
#     neigh         (Nc, numsides) int32 ...
#     grad          (Ne, Two) int32 ...
#     xp            (Np) float64 ...
#     yp            (Np) float64 ...
#     normal        (Nc, numsides) int32 ...
#     n1            (Ne) float64 ...
# ...

# %%
ptm5.Mesh2_edge_bottom_layer.isel(nMesh2_data_time=224).values.max()
# Out:
# 50.0

# %%
ptm5.Mesh2_edge_bottom_layer.isel(nMesh2_data_time=225).values.max()

# %%
ptm5.Mesh2_edge_bottom_layer.isel(nMesh2_data_time=-1).values.max()

# %%
ls /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm*.nc
# Out:
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0000.nc
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0001.nc
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0002.nc
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0003.nc
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0004.nc
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0005.nc
# /opt2/sfb_ocean/suntans/runs/merge_009-20170601/ptm_average.nc_0006.nc

# %%
avg0.h_flow_avg.isel(nMesh2_)
# Out:
# <xarray.DataArray 'h_flow_avg' (nMesh2_edge: 108448, nMesh2_layer_3d: 50, nMesh2_data_time: 239)>
# [1295953600 values with dtype=float64]
# Coordinates:
#     Mesh2_edge_x  (nMesh2_edge) float64 ...
#     Mesh2_edge_y  (nMesh2_edge) float64 ...
# Dimensions without coordinates: nMesh2_edge, nMesh2_layer_3d, nMesh2_data_time
# Attributes:
#     long_name:    Horizontal volume flux averaged over integration interval
#     units:        m3 s-1
#     coordinates:  Mesh2_edge_x Mesh2_edge_y Mesh2_edge_z_3d

# %%
g=unstructured_grid.UnstructuredGrid.from_ugrid(avg0orig)

# %%
bad_part=np.array([539605.92406999995,4187527.0580000002])

# %%
plt.figure()
g.plot_edges()
plt.plot([bad_part[0]],[bad_part[1]],'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
avg0.Mesh2_vertical_diffusivity_3d.isel(nMesh2_data_time=238).min()
# Out:
# <xarray.DataArray 'Mesh2_vertical_diffusivity_3d' ()>
# array(0.)
